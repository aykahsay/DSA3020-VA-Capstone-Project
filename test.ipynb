# %%
from src.config import settings
import os

print("Base Directory:", settings.BASE_DIR)
print("Raw Directory:", settings.RAW_DIR)
print("Database Directory:", settings.DATABASE_DIR)
print("AGRIBORA CSV Path:", settings.AGRIBORA_CSV)
print("KAMIS Raw CSV Path:", settings.KAMIS_RAW_CSV)
print("KAMIS CSV Path:", settings.KAMIS_CSV)

# Optional: Check if files exist
print("AGRIBORA CSV exists:", os.path.exists(settings.AGRIBORA_CSV))
print("KAMIS Raw CSV exists:", os.path.exists(settings.KAMIS_RAW_CSV))
print("KAMIS CSV exists:", os.path.exists(settings.KAMIS_CSV))
# Out:
# Base Directory: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA
# Raw Directory: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA\raw
# Database Directory: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA\database
# AGRIBORA CSV Path: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA\raw\agribora_maize_prices.csv
# KAMIS Raw CSV Path: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA\raw\kamis_maize_prices_raw.csv
# KAMIS CSV Path: c:\Users\Admin\DSA3020-VA-Capstone-Project\DATA\raw\kamis_maize_prices.csv
# AGRIBORA CSV exists: True
# KAMIS Raw CSV exists: True
# KAMIS CSV exists: True

# %%
import pandas as pd
from src.config import settings

df = pd.read_csv(settings.KAMIS_CSV, on_bad_lines='skip')
print(df.head())
# Out:
#                                                                                                                              900.0  \
# Dry_White_Maize             Dry_Maize White_Maize       Baringo Marigat_Market       2021-05-24 2021 5 2021-05 21 2021-21  14000.0
#                                                                 Kabarnet_Market      2021-05-24 2021 5 2021-05 21 2021-21   2700.0
#                                                                 Marigat_Market       2021-05-24 2021 5 2021-05 21 2021-21  14000.0
#                                                                                                                   2021-21  14000.0
# Dry_Maize_Mixed_Traditional Dry_Maize Mixed_Traditional Baringo Eldama_Ravine_Market 2021-05-24 2021 5 2021-05 21 2021-21      0.0
#
#                                                                                                                            40.0  \
# ...

# %%
df.shape
# Out:
# (21887, 4)
